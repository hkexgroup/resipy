# %% [markdown]
# # Batch inversion
# Batch inversion is the fact to allow to invert multiple surveys in once. Here we reuse a lot of stuff from the time-lapse implementation.

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import os
import sys
sys.path.append((os.path.relpath('../src/'))) # add here the relative path of the API folder

from api.R2 import R2

# %%
k = R2()
k.createBatchSurvey('../src/api/test/testTimelapse')
# Out:
# Working directory is: /media/jkl/data/phd/tmp/pyr2/src/api/invdir
# clearing the dirname
# 36/344 reciprocal measurements NOT found.
# 0 measurements error > 20 %
# 17031501.csv imported
# --------- 17031501.csv imported
# 36/344 reciprocal measurements NOT found.
# 0 measurements error > 20 %
# 17040301.csv imported
# --------- 17040301.csv imported
# 36/344 reciprocal measurements NOT found.
# 0 measurements error > 20 %
# 17042701.csv imported
# --------- 17042701.csv imported
# 36/344 reciprocal measurements NOT found.
# 0 measurements error > 20 %
# 17051601.csv imported
# --------- 17051601.csv imported
# creating bigSurvey
# 36/344 reciprocal measurements NOT found.
# 0 measurements error > 20 %

# %% [markdown]
# And inversion as usual.

# %%
k.invert(iplot=False)
# Out:
# Writing .in file and protocol.dat ...
# written mesh.dat file to
# /media/jkl/data/phd/tmp/pyr2/src/api/invdir/mesh.dat
# print in iBatch format
# done
#
# -------- Main inversion ---------------
#
#
#
#  >> R  2    R e s i s t i v i t y   I n v e r s i o n   v3.2 <<
#
#  >> D a t e : 26 - 11 - 2018
#  >> My beautiful survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading start resistivity from res0.dat
#  >> R e g u l a r i s e d   T y p e <<
#  >>   L i n e a r    F i l t e r    <<
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#  >> D a t a   w e i g h t s   w i l l   b e  m o d i f i e d <<
#
#
#  Processing dataset   1
#
#
#  Measurements read:   154     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.52134E+02
#
#  >> Total Memory required is:          0.238 Gb
#
#    Iteration   1
#      Initial RMS Misfit:        28.36     Number of data ignored:     0
#      Alpha:    245.964   RMS Misfit:        1.21
#      Alpha:    114.166   RMS Misfit:        1.27
#      Step length set to   1.00000
#      Final RMS Misfit:        1.21
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.03     Number of data ignored:     0
#      Alpha:    123.519   RMS Misfit:        0.36
#      Step length set to   1.00000
#      Final RMS Misfit:        0.36
#      Final RMS Misfit:        1.00
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   2
#
#
#  Measurements read:   154     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.53798E+02
#
#    Iteration   1
#      Initial RMS Misfit:        26.86     Number of data ignored:     0
#      Alpha:    247.755   RMS Misfit:        1.20
#      Alpha:    114.998   RMS Misfit:        1.26
#      Step length set to   1.00000
#      Final RMS Misfit:        1.20
#      Attempted to update data weights and caused overshoot
#      treating as converged
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   3
#
#
#  Measurements read:   154     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.63324E+02
#
#    Iteration   1
#      Initial RMS Misfit:        20.44     Number of data ignored:     0
#      Alpha:    256.906   RMS Misfit:        2.50
#      Alpha:    119.245   RMS Misfit:        2.63
#      Step length set to   1.00000
#      Final RMS Misfit:        2.50
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         1.88     Number of data ignored:     0
#      Alpha:    143.478   RMS Misfit:        0.63
#      Step length set to   1.00000
#      Final RMS Misfit:        0.63
#      Final RMS Misfit:        1.03
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   4
#
#
#  Measurements read:   154     Measurements rejected:     0
#    Geometric mean of apparent resistivities:  0.70533E+02
#
#    Iteration   1
#      Initial RMS Misfit:        16.93     Number of data ignored:     0
#      Alpha:    262.728   RMS Misfit:        3.72
#      Alpha:    121.948   RMS Misfit:        3.73
#      Step length set to   1.00000
#      Final RMS Misfit:        3.72
#      Updated data weights
#
#    Iteration   2
#      Initial RMS Misfit:         2.56     Number of data ignored:     0
#      Alpha:    156.718   RMS Misfit:        1.05
#      Alpha:     72.742   RMS Misfit:        0.71
#      Step length set to   1.00000
#      Final RMS Misfit:        0.71
#      Final RMS Misfit:        1.02
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#
#  Processing dataset   5
#
#
#  End of data:  Terminating

# %% [markdown]
# And each inverted section can be shown using the same function `R2.showResults()`.

# %%
k.showResults(index=0, contour=True, vmin=1.5, vmax=2)
k.showResults(index=1, contour=True, vmin=1.5, vmax=2)
k.showResults(index=2, contour=True, vmin=1.5, vmax=2)
k.showResults(index=3, contour=True, vmin=1.5, vmax=2)
# Out:
# reading  /media/jkl/data/phd/tmp/pyr2/src/api/invdir/f001_res.vtk
# reading  /media/jkl/data/phd/tmp/pyr2/src/api/invdir/f002_res.vtk
# reading  /media/jkl/data/phd/tmp/pyr2/src/api/invdir/f003_res.vtk
# reading  /media/jkl/data/phd/tmp/pyr2/src/api/invdir/f004_res.vtk
# Mesh plotted in 0.18119 seconds
# Mesh plotted in 0.15578 seconds
# Mesh plotted in 0.19585 seconds
# Mesh plotted in 0.16618 seconds
