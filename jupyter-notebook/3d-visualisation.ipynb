# %% [markdown]
# # 3D viewing
# This notebook will show how to display 3D results with resipy in a notebook. Note that 3D viewing is based on the Python package: *pyvista* that needs to be installed (`pip install pyvista`).

# %%
import sys
sys.path.append('.')
from resipy import R2
import pyvista as pv
testdir = 'examples/'

# %%
k = R2(typ='R3t')
k.createSurvey(testdir + 'dc-3d/protocol.dat', ftype='Protocol')
k.importElec(testdir + 'dc-3d/elec.csv')
k.createMesh()
k.invert()
# Out:
# Working directory is: /media/jkl/data/phd/tmp/pyr2/src/resipy/invdir
# clearing the dirname
# 644/644 reciprocal measurements NOT found.
# 0 measurements error > 20 %
# Creating tetrahedral mesh...doi in gmshWrap.py: -32.687068
# writing .geo to file completed, save location:
# /media/jkl/data/phd/tmp/pyr2/src/resipy/invdir
#
# parsing gmsh mesh...
#
# importing node coordinates...
# reading connection matrix...
# ignoring 10551 non-tetrahedra (or prism) elements in the mesh file, as they are not required for R3t
# interpolating topography onto mesh using triangulate interpolation...done
# done
# Writing .in file and protocol.dat...done!
# --------------------- MAIN INVERSION ------------------
#
#
#  >> R 3 t     E R T    M o d e l    v2.0 <<
#
#  >> Date: 08-04-2020
#  >> My beautiful 3D survey
#  >> I n v e r s e   S o l u t i o n   S e l e c t e d <<
#  >> T e t r a h e d r a l   E l e m e n t   M e s h <<
#
#  >> Reading mesh file
#  >> Determining storage needed for finite element conductance matrix
#  >> Generating index array for finite element conductance matrix
#  >> Reading resistivity model from res0.dat
#
#  >> L o g - D a t a   I n v e r s i o n <<
#  >> N o r m a l   R e g u l a r i s a t i o n <<
#
#  >> Memory estimates:
#     For   1000 measurements the memory needed is:          0.479 Gb
#     For   2000 measurements the memory needed is:          0.941 Gb
#     For   5000 measurements the memory needed is:          2.327 Gb
#     For  10000 measurements the memory needed is:          4.638 Gb
#
#  >> Forming roughness matrix
#
#  >> Number of measurements read:  644
#
#  >> Total Memory required is:          0.314 Gb
#
#
#  Processing frame   1 - output to file f001.dat
#
#    Iteration   1
#      Initial RMS Misfit:         2.31      Number of data ignored:     0
#      Alpha:          59.454   RMS Misfit:        0.51  Roughness:        2.933
#      Step length set to      1.000
#      Final RMS Misfit:        0.51
#      Final RMS Misfit:        1.01
#
#  Solution converged - Outputing results to file
#
#  Calculating sensitivity map
#
#  End of data:  Terminating
#
#
#  >> Program ended normally
#
# 1/1 results parsed (1 ok; 0 failed)

# %% [markdown]
# ## Options available
# - `pvslices`: a tuple of list, each list represent the coordinates of an slice orthogonal to X, Y and Z respectively
# - `pvthreshold` : a list of two values representing the minimum and maximum values between which to keep the cells
# - `pvcontour` : a list of values at which draw isosurfaces
# - `pvgrid`: a bool, if `True`, the grid is plotted

# %%
pl = pv.Plotter()
k.showResults(ax=pl)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F167ACC1F98>

# %%
pl = pv.Plotter()
k.showResults(ax=pl, pvslices=([5,15,25,35,45],[0],[]), pvgrid=True, vmin=1.95, vmax=2.2, color_map='plasma')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F15F36647B8>

# %%
pl = pv.Plotter()
k.showResults(ax=pl, pvthreshold=[2.1, 2.2], pvgrid=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F15F363F780>

# %%
pl = pv.Plotter()
k.showResults(ax=pl, pvcontour=[2, 2.1], pvgrid=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F15F36640B8>
